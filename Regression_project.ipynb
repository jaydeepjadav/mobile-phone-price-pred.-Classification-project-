# %% [markdown]
# <a href="https://colab.research.google.com/github/jaydeepjadav/nairobi-public-transport-Regression-project-/blob/main/Regression_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -   Demand Prediction For Public Transport

# %% [markdown]
# ##### **Project Type**    - Regression
# ##### **Contribution**    - Individual
# ##### **Team Member -**  JAYDEEP JADAV

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Regression project on Demand prediction of Public Transport of Nairobi was carried out individually by **Jaydeep Jadav**. For this project a csv file was provided containing the data of 14 routes and all routes start with different origin and end in Nairobi. The dataset contains 10 columns and 51645 rows. Reason for me to choose this topic was because I had the prior knowledge of transportation system as I have been using road transportaion system for travelling purpose.
#
# After that I spend some time understanding the data/variables provided to get the idea in what direction to move with this project. Then started the project with importing the libraries, uploading dataset, defining the dataframe as 'df'
# , then comes the firstlook of dataset, next was undersatnding the variables, then started doing data wrangling and at last specified the Target variable as it was not provided.
#
# In the second part of the project I started EDA of the given data with different type of analysis univariate, bivariate and multivariate. And along with EDA in between I also did some feature engineering to add some more columns by extracting the data from the existing given columns in order to increase the no. of features so that model complexity can increase and save model to go underfit.
#
# After doing feature engineering between EDA, there was feature selection and data processing was left, that is dropping some of the unwanted features, checking for mulicolinearity and data encoding.
#
# And then at last, model implementaion. Started with splitting the data into train and test data. I didn't use data scaling as most of the columns had data encoded values or date and time. In model implementaion I tried to go with most of the regression techniques that have been taught linear, ridge, lasso, random forest, XGBoost and along with them I also did some hyperparameter tunning of random forest and XGboost.
#
# With end result of model implementations, this project was concluded.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This challenge asked me to build a model that predicts the number of seats that Mobiticket can expect to sell for each ride, i.e. for a specific route on a specific date and time. There are 14 routes in this dataset. All of the routes end in Nairobi and originate in towns to the North-West of Nairobi towards Lake Victoria.
#
# The towns from which these routes originate are:
# - Awendo
# - Homa Bay
# - Kehancha
# - Kendu Bay
# - Keroka
# - Keumbu
# - Kijauri
# - Kisii
# - Mbita
# - Migori
# - Ndhiwa
# - Nyachenge
# - Oyugis
# - Rodi
# - Rongo
# - Sirare
# - Sori
#
# Passengers of these bus (or shuttle) rides are affected by Nairobi traffic not only during their ride into the city, but from there they must continue their journey to their final destination in Nairobi wherever that may be. Traffic can act as a deterrent for those who have the option to avoid buses that arrive in Nairobi during peak traffic hours. On the other hand, traffic may be an indication for people’s movement patterns, reflecting business hours, cultural events, political events, and holidays.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/Nairobi Transport Data.zip')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    ride_id seat_number payment_method payment_receipt travel_date travel_time  \
# 0     1442         15A          Mpesa      UZUEHCBUSO    17-10-17        7:15
# 1     5437         14A          Mpesa      TIHLBUSGTE    19-11-17        7:12
# 2     5710          8B          Mpesa      EQX8Q5G19O    26-11-17        7:05
# 3     5777         19A          Mpesa      SGP18CL0ME    27-11-17        7:10
# 4     5778         11A          Mpesa      BM97HFRGL9    27-11-17        7:12
#
#   travel_from travel_to car_type  max_capacity
# 0      Migori   Nairobi      Bus            49
# 1      Migori   Nairobi      Bus            49
# 2      Keroka   Nairobi      Bus            49
# 3    Homa Bay   Nairobi      Bus            49
# 4      Migori   Nairobi      Bus            49

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (51645, 10)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51645 entries, 0 to 51644
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ride_id          51645 non-null  int64
#  1   seat_number      51645 non-null  object
#  2   payment_method   51645 non-null  object
#  3   payment_receipt  51645 non-null  object
#  4   travel_date      51645 non-null  object
#  5   travel_time      51645 non-null  object
#  6   travel_from      51645 non-null  object
#  7   travel_to        51645 non-null  object
#  8   car_type         51645 non-null  object
#  9   max_capacity     51645 non-null  int64
# dtypes: int64(2), object(8)
# memory usage: 3.9+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().any()
# Out:
# False

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# ride_id            0
# seat_number        0
# payment_method     0
# payment_receipt    0
# travel_date        0
# travel_time        0
# travel_from        0
# travel_to          0
# car_type           0
# max_capacity       0
# dtype: int64

# %%
# Visualizing the missing values
temp = sns.relplot(df.isnull().sum())
temp.set_xticklabels(rotation =45)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The given dataset is consist of 10 columns and 51645 entries(columns) which having the data regarding public road transport system of Nairobi(Kenya).
#
# From the given dataset have to predict the sales of ticket for each ride for the ticket booking company MOBITICKET keeping in mind various factors  like traffic, routes etc.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['ride_id', 'seat_number', 'payment_method', 'payment_receipt',
#        'travel_date', 'travel_time', 'travel_from', 'travel_to', 'car_type',
#        'max_capacity'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include="all").T
# Out:
#                    count unique         top   freq          mean          std  \
# ride_id          51645.0    NaN         NaN    NaN  10188.645793  2211.295708
# seat_number        51645     61           1   2065           NaN          NaN
# payment_method     51645      2       Mpesa  51532           NaN          NaN
# payment_receipt    51645  51645  UZUEHCBUSO      1           NaN          NaN
# travel_date        51645    149    10-12-17    856           NaN          NaN
# travel_time        51645     78        7:09   3926           NaN          NaN
# travel_from        51645     17       Kisii  22607           NaN          NaN
# travel_to          51645      1     Nairobi  51645           NaN          NaN
# car_type           51645      2         Bus  31985           NaN          NaN
# max_capacity     51645.0    NaN         NaN    NaN     34.534321    18.451193
#
#                     min     25%      50%      75%      max
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **ride_id** - id number of ticket generated
#
# **seat_number** - passenger seat number booked
#
# **payment_method** - mode of payment
#
# **payment_receipt** - payment receipt / confirmation of payment
#
# **travel_date** - date of journey
#
# **travel_time** - time of departure from the station
#
# **travel_from** - boarding station of passenger
#
# **travel_to** - destination of passenger
#
# **car_type** - type of vehicle/means of transportation
#
# **max_capacity** - maximum number of passenger vehicle can accommodate

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# ride_id             6249
# seat_number           61
# payment_method         2
# payment_receipt    51645
# travel_date          149
# travel_time           78
# travel_from           17
# travel_to              1
# car_type               2
# max_capacity           2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
#checking for null values
df.isnull().sum()
# Out:
# ride_id            0
# seat_number        0
# payment_method     0
# payment_receipt    0
# travel_date        0
# travel_time        0
# travel_from        0
# travel_to          0
# car_type           0
# max_capacity       0
# dtype: int64

# %%
#checking for duplicate values
df.nunique()
# Out:
# ride_id             6249
# seat_number           61
# payment_method         2
# payment_receipt    51645
# travel_date          149
# travel_time           78
# travel_from           17
# travel_to              1
# car_type               2
# max_capacity           2
# dtype: int64

# %% [markdown]
# As there are 6249 unique ride ids where the booking entries are 51645 that means multiple tickets were booked from same ids.

# %% [markdown]
# ## **Finding the Target Variable**

# %% [markdown]
# As no specific Target variable is provided, our main objective is predicting sales of tickets, so ride id represents the no of bookings occured, but there are multiple tickets booked from same ids, from ride id we can get the total no of tickets booked individually.

# %%
#creating a temproray dataset to get number of tickets booked
ticket_df = df.groupby(['ride_id']).seat_number.count().rename('tickets_booked').reset_index()
ticket_df
# Out:
#       ride_id  tickets_booked
# 0        1442               1
# 1        5437               1
# 2        5710               1
# 3        5777               5
# 4        5778              31
# ...       ...             ...
# 6244    20113               9
# 6245    20114               4
# 6246    20115               5
# 6247    20116               1
# 6248    20117               1
#
# [6249 rows x 2 columns]

# %%
#dropping the existing duplicate values of ride_id
df.drop_duplicates('ride_id',inplace=True)

# %%
#merging the two dataset to get updated dataset with train and targeted variables
df = df.merge(ticket_df, how = "left", on='ride_id')
df.head()
# Out:
#    ride_id seat_number payment_method payment_receipt travel_date travel_time  \
# 0     1442         15A          Mpesa      UZUEHCBUSO    17-10-17        7:15
# 1     5437         14A          Mpesa      TIHLBUSGTE    19-11-17        7:12
# 2     5710          8B          Mpesa      EQX8Q5G19O    26-11-17        7:05
# 3     5777         19A          Mpesa      SGP18CL0ME    27-11-17        7:10
# 4     5778         11A          Mpesa      BM97HFRGL9    27-11-17        7:12
#
#   travel_from travel_to car_type  max_capacity  tickets_booked
# 0      Migori   Nairobi      Bus            49               1
# 1      Migori   Nairobi      Bus            49               1
# 2      Keroka   Nairobi      Bus            49               1
# 3    Homa Bay   Nairobi      Bus            49               5
# 4      Migori   Nairobi      Bus            49              31

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Since there are no null values or duplicate values, zero changes were made in columns.
#
# New column has been created for target variable as tickets booked. As no specific Target variable is provided, our main objective is predicting sales of tickets.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1   (bivariate with categorical - numerical)

# %%
# Chart - 1 visualization code
chart1A = df.groupby('payment_method')['tickets_booked'].count()
chart1A.plot(kind="pie",
             startangle=90,
             shadow= False,
             fontsize=20,
             explode=[0,0.5])
# Out:
# <Axes: ylabel='tickets_booked'>

# %%
chart1B = df.groupby('car_type')['tickets_booked'].count()
clr = ['lightgreen','darkgreen']
chart1B.plot(kind='pie',startangle=180,colors=clr,
             shadow=True,fontsize=20)
# Out:
# <Axes: ylabel='tickets_booked'>

# %%
chart1C = df.groupby('max_capacity')['tickets_booked'].count()
chart1C.plot(kind='pie',shadow = True,
             startangle=0,fontsize=20 )
# Out:
# <Axes: ylabel='tickets_booked'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For discrete categorical data pie chart representation makes it easier to read and understand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1- Majorly people uses mpesa as transaction
#
# 2- From car_type and max_capacity data got the idea that shuttle and bus have 11 and 49 seats respectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# For better convenience mpesa should be default payment transaction method, that'll create better customer experiance.

# %% [markdown]
# #### Chart - 2 (Univariate)

# %%
# Chart - 2 visualization code
plt.figure(figsize=(15,7))
chart2 = sns.countplot(x=df['tickets_booked'])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have used bar charts to represent dependent variable ditribution, Bar charts are useful to compare different categorical or discrete variables as long as they are too many categories to compare.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Mostly at a time people books upto 11 tickets, and even in that single tickets are generating more sales.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Through Mobiticket it should be convenient to book multiple tickets. Atleast upto 11-12 tickets.

# %% [markdown]
# #### Chart - 3  (univariate)

# %%
# Chart - 3 visualization code
plt.rcParams['figure.figsize']=(12,7)
chart3 =  df.groupby('travel_from')['tickets_booked'].count()
chart3 =  chart3.sort_values(ascending=False)
chart3.plot(kind='bar',color='lightblue',edgecolor='teal')
# Out:
# <Axes: xlabel='travel_from'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have used bar charts to represent dependent variable ditribution, Bar charts are useful to compare different categorical or discrete variables as long as they are too many categories to compare.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Graph is showing from which city how much tickets are booked

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The three stops that all these routes make in Nairobi (in order) are:
# - Kisii
# - Rongo
# - Kijauri

# %% [markdown]
# #### Chart - 4 (multivariate with numerical-categorical)

# %%
# Chart - 4 visualization code
variable = df.groupby(['travel_from','payment_method'])['tickets_booked'].count().reset_index()
chart4 = variable.pivot('travel_from','payment_method').reset_index()
clr=  ['darkblue','thistle']
chart4.set_index('travel_from').plot(kind='bar', stacked =False,
                                    figsize=(18,9),
                                    title="Grouped bar graph",
                                     color=clr,
                                    edgecolor='dimgray'
                                    )
# Out:
# <ipython-input-25-83064045162c>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   chart4 = variable.pivot('travel_from','payment_method').reset_index()
# <Axes: title={'center': 'Grouped bar graph'}, xlabel='travel_from'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have used bar charts to represent dependent variable ditribution, Bar charts are useful to compare different categorical or discrete variables as long as they are too many categories to compare.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this graph we can conclude in which city what payment method is more acceptable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Mostly mpesa is used in every city except Kisii, in Kisii a small amount of portion uses cash as transaction method.

# %% [markdown]
# #### Chart - 5  (multivariate with categorical- numerical)

# %%
# Chart - 5 visualization code
variable = df.groupby(['travel_from','car_type'])['tickets_booked'].count().reset_index()
chart5 = variable.pivot('travel_from','car_type').reset_index()
clr=  ['crimson','burlywood']
chart5.set_index('travel_from').plot(kind='bar', stacked =False,
                                    figsize=(18,9),
                                    title="Grouped bar graph",
                                     color=clr,
                                    edgecolor='red'
                                    )
# Out:
# <ipython-input-26-9a10da75add5>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   chart5 = variable.pivot('travel_from','car_type').reset_index()
# <Axes: title={'center': 'Grouped bar graph'}, xlabel='travel_from'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have used bar charts to represent dependent variable ditribution, Bar charts are useful to compare different categorical or discrete variables as long as they are too many categories to compare.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In which city what type of public transportaion is more favorable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In Kisii and Kijauri shuttle are used more than buses Where as in rest of the origin place buses are dominating the market.

# %% [markdown]
# #### Chart - 6 (multivariate with categorical - numerical)

# %%
# Chart - 6 visualization code
variable = df.groupby(['seat_number','car_type'])['tickets_booked'].count().reset_index()
chart6 = variable.pivot('seat_number','car_type').reset_index()
clr=  ['orangered','lightseagreen']
chart6.set_index('seat_number').plot(kind='bar', stacked =False,
                                    figsize=(18,9),
                                    title="Grouped bar graph",
                                     color=clr,
                                    edgecolor='white'
                                    )
# Out:
# <ipython-input-27-f723a763d81b>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   chart6 = variable.pivot('seat_number','car_type').reset_index()
# <Axes: title={'center': 'Grouped bar graph'}, xlabel='seat_number'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have used bar charts to represent dependent variable ditribution, Bar charts are useful to compare different categorical or discrete variables as long as they are too many categories to compare.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There are few seat numbers which are more preferable by customer
#
#
# *   in BUS 1B,25,24A are more preferable
# *   in shuttle 1,10,1X are more preferable

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As Chances of getting preferable seats, customer is more likely to book tickets. Just like flight booking.

# %% [markdown]
# #### Adding features

# %%
#copying data to new dataframe variable
new_df = df.copy()

# %% [markdown]
# Extracting date and time data in more useable form

# %%
import datetime

# %%
#combining date and time column into one
new_df['date_time'] = new_df['travel_date'] + " " + new_df['travel_time']
new_df['date_time'] = pd.to_datetime(new_df['date_time'])

# %%
#dropping existing date column and time column
new_df.drop(['travel_date','travel_time'],inplace=True,axis=1)

# %%
#extracting required date and time columns information

new_df['month'] = new_df['date_time'].dt.month
new_df['year'] = new_df['date_time'].dt.year
new_df['hour'] = new_df['date_time'].dt.hour
new_df['day_of_year'] = new_df['date_time'].dt.day_of_year
new_df['day_of_month'] = new_df['date_time'].dt.day
new_df['day_of_week'] = new_df['date_time'].dt.dayofweek
new_df['quarter_of_year'] = new_df['date_time'].dt.quarter
new_df['weekend_travels'] = new_df['date_time'].apply( lambda x: 1 if x in [5,6] else 0)

# %%
new_df.nunique()
# Out:
# ride_id            6249
# seat_number          60
# payment_method        2
# payment_receipt    6249
# travel_from          17
# travel_to             1
# car_type              2
# max_capacity          2
# tickets_booked       50
# date_time          4579
# month                12
# year                  2
# hour                  9
# day_of_year         149
# day_of_month         24
# day_of_week           7
# quarter_of_year       4
# weekend_travels       1
# dtype: int64

# %%
def time_of_day(i):
  if i<7 :
    return 'early morning'
  elif i>=7 and i<12:
    return 'morning'
  elif i>=12 and i<16:
    return  'afternoon'
  elif i>=16 and i<19:
    return  'evening'
  else:
    return  'night'

# %%
# this column will show which time period of day
new_df['travelling_period'] = new_df.hour.apply(time_of_day)

# %%
temp_var = dict(new_df.travelling_period.value_counts())
new_df['hourly_travellers'] = np.log1p(new_df.travelling_period.map(temp_var))

# %%
# creating new coulmn for daily travellers
temp_var2 = dict(new_df.day_of_year.value_counts())
new_df['daily_travellers'] = np.log1p(new_df.day_of_year.map(temp_var2))

# %%
#Creating a function to calculate frequancy of buses
def calculate_next_and_previous_timings(tmp_df):

  tmp_df.sort_values(['travel_from', 'date_time'], inplace= True)
  tmp_df['delay_btw_initial_to_next_and_previous_bus'] = (tmp_df.groupby(['travel_from']).date_time.shift(-1) - tmp_df.groupby(['travel_from']).date_time.shift(1)).dt.total_seconds()/3600
  tmp_df['delay_btw_1bus_and_next_bus'] = (tmp_df.date_time - tmp_df.groupby(['travel_from']).date_time.shift(-1)).dt.total_seconds()/3600
  tmp_df['delay_btw_1bus_and_previous_bus'] = (tmp_df.date_time - tmp_df.groupby(['travel_from']).date_time.shift(1)).dt.total_seconds()/3600
  tmp_df['delay_btw_2bus_and_next_bus'] = (tmp_df.date_time - tmp_df.groupby(['travel_from']).date_time.shift(-2)).dt.total_seconds()/3600
  tmp_df['delay_btw_2bus_and_previous_bus'] = (tmp_df.date_time - tmp_df.groupby(['travel_from']).date_time.shift(2)).dt.total_seconds()/3600
  tmp_df['delay_btw_3bus_and_next_bus'] = (tmp_df.date_time - tmp_df.groupby(['travel_from']).date_time.shift(-3)).dt.total_seconds()/3600
  tmp_df['delay_btw_3bus_and_previous_bus'] = (tmp_df.date_time - tmp_df.groupby(['travel_from']).date_time.shift(3)).dt.total_seconds()/3600
  new_col = ['delay_btw_initial_to_next_and_previous_bus', 'delay_btw_1bus_and_next_bus', 'delay_btw_1bus_and_previous_bus', 'delay_btw_2bus_and_next_bus', 'delay_btw_2bus_and_previous_bus', 'delay_btw_3bus_and_next_bus','delay_btw_3bus_and_previous_bus']
  tmp_df[new_col] = tmp_df.groupby(['travel_from'])[new_col].fillna(method = 'ffill')
  tmp_df[new_col] = tmp_df.groupby(['travel_from'])[new_col].fillna(method = 'backfill')

  return tmp_df

# %%
new_df = calculate_next_and_previous_timings(new_df)

# %%
new_df.head()
# Out:
#       ride_id seat_number payment_method payment_receipt travel_from  \
# 502      6654         24B          Mpesa      UMAPNYPBAS      Awendo
# 5530    12926          25          Mpesa      NOXLCPZ2MO      Awendo
# 5533    12929         16A          Mpesa      VSJSFSMOFG      Awendo
# 5539    12935         21B          Mpesa      2MLD47XLVU      Awendo
# 5528    12924         16B          Mpesa      6KYCTDYHDJ      Awendo
#
#      travel_to car_type  max_capacity  tickets_booked           date_time  \
# 502    Nairobi      Bus            49               2 2017-05-12 07:08:00
# 5530   Nairobi      Bus            49              20 2018-01-04 07:08:00
# 5533   Nairobi      Bus            49               2 2018-01-04 07:12:00
# 5539   Nairobi      Bus            49               9 2018-01-04 07:13:00
# 5528   Nairobi      Bus            49              15 2018-01-04 08:00:00
#
#       ...  travelling_period  hourly_travellers  daily_travellers  \
# ...

# %%
new_df.isnull().sum()
# Out:
# ride_id                                       0
# seat_number                                   0
# payment_method                                0
# payment_receipt                               0
# travel_from                                   0
# travel_to                                     0
# car_type                                      0
# max_capacity                                  0
# tickets_booked                                0
# date_time                                     0
# month                                         0
# year                                          0
# hour                                          0
# day_of_year                                   0
# day_of_month                                  0
# day_of_week                                   0
# quarter_of_year                               0
# weekend_travels                               0
# travelling_period                             0
# hourly_travellers                             0
# ...

# %%
#dropping null values
new_df.dropna(inplace=True)

# %%
#finding the distance of each origin point from the distination point.
travelling_distance_to_Nairobi_dict = {'Awendo':352, 'Homa Bay':368, 'Kehancha':308, 'Kendu Bay':343, 'Keroka':281, 'Keumbu':295,
                                   'Kijauri':272, 'Kisii':306, 'Mbita':406, 'Migori':373, 'Ndhiwa':385, 'Nyachenge':313, 'Oyugis':324,
                                   'Rodi':348, 'Rongo':333, 'Sirare':415, 'Sori':407}
new_df['travelling_distance_to_Nairobi'] = new_df.travel_from.map(travelling_distance_to_Nairobi_dict)

# %%
# travelling time from the origin to Nairobi
travelling_time_to_Nairobi_dict = {'Awendo': 6*60+24, 'Homa Bay': 6*60+29, 'Kehancha': 6*60+11, 'Kendu Bay': 6*60, 'Keroka': 4*60+55, 'Keumbu': 5*60+13, 'Kijauri': 4*60+44,
 'Kisii': 5*60+29, 'Mbita': 7*60+8, 'Migori': 6*60+54, 'Ndhiwa': 6*60+47, 'Nyachenge': 5*60+40, 'Oyugis': 5*60+42, 'Rodi': 6*60+40, 'Rongo': 6*60+5, 'Sirare': 8*60+4, 'Sori': 7*60+11}
new_df['travelling_time_to_Nairobi'] = new_df.travel_from.map(travelling_time_to_Nairobi_dict)

# %%
new_df["speed"] = new_df.travelling_distance_to_Nairobi/new_df.travelling_time_to_Nairobi

# %%
new_df.head()
# Out:
#       ride_id seat_number payment_method payment_receipt travel_from  \
# 502      6654         24B          Mpesa      UMAPNYPBAS      Awendo
# 5530    12926          25          Mpesa      NOXLCPZ2MO      Awendo
# 5533    12929         16A          Mpesa      VSJSFSMOFG      Awendo
# 5539    12935         21B          Mpesa      2MLD47XLVU      Awendo
# 5528    12924         16B          Mpesa      6KYCTDYHDJ      Awendo
#
#      travel_to car_type  max_capacity  tickets_booked           date_time  \
# 502    Nairobi      Bus            49               2 2017-05-12 07:08:00
# 5530   Nairobi      Bus            49              20 2018-01-04 07:08:00
# 5533   Nairobi      Bus            49               2 2018-01-04 07:12:00
# 5539   Nairobi      Bus            49               9 2018-01-04 07:13:00
# 5528   Nairobi      Bus            49              15 2018-01-04 08:00:00
#
#       ...  delay_btw_initial_to_next_and_previous_bus  \
# ...

# %% [markdown]
# #### Chart - 7 (Pair plot)

# %%
# Chart - 7 visualization code
cols_to_work = new_df[['month','year','hour','day_of_month','day_of_week']].copy()
sns.pairplot(cols_to_work)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plot is used to understand the best set of features to explain a relationship between two variables or to form the most separated clusters.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above pairplot we can get understanding of time related  sales of tickets, on which days or between what daily hours tickets are sold highest or lowest.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1.   We can see that there is the gap between 5 to 11 in the day of the month
# 2.   There is not ride between 11:30am to 5:30Pm
# 3.   In June,July and August there are few buses on 3rd day.

# %% [markdown]
# #### Chart - 8 (Bivariate with Categorical-time value)

# %%
# Chart - 8 visualization code
chart8a = sns.scatterplot(x='travel_from',y='hour',data=new_df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# As for multiple data points and categories scatter plot shows more specific coordinates which makes it easier to understand and provides a better readability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is not ride between 11:30am to 5:30Pm from any origin.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Everyday at 7am most tickets are sold compared to any other hour of day.

# %% [markdown]
# #### Chart - 9 (Multivariate with time-target variable)

# %%
# Chart - 9 visualization code
temp = new_df.groupby(['month','year'])['tickets_booked'].count().reset_index()
chart9 = temp.pivot('month','year').reset_index()
chart9.set_index('month').plot(kind='area',stacked=False)
# Out:
# <ipython-input-49-5ccc4695b1d8>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   chart9 = temp.pivot('month','year').reset_index()
# <Axes: xlabel='month'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason for choosing area chart is to get the cumulated data and from it conclude generalise idea of tickets that
# they were sold.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In which month(s) the most tickets were sold.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Most of the tickets were sold between November of 2017 and May of 2018.

# %% [markdown]
# #### Chart - 10 (Bivariate with Categorical-time value)

# %%
# Chart - 10 visualization code
new_df.plot(x='month',y='travel_from',kind='scatter')
# Out:
# <Axes: xlabel='month', ylabel='travel_from'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# As for multiple data points and categories scatter plot shows more specific coordinates which makes it easier to understand and provides a better readability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This graph can give better idea on which origin city to focus on what month of the year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Ndhawa,Sori,Rodi and Mbita are few origins where in the first six months no tickets were sold.

# %% [markdown]
# # Feature engineering And Data preprocessing

# %%
new_df.head()
# Out:
#       ride_id seat_number payment_method payment_receipt travel_from  \
# 502      6654         24B          Mpesa      UMAPNYPBAS      Awendo
# 5530    12926          25          Mpesa      NOXLCPZ2MO      Awendo
# 5533    12929         16A          Mpesa      VSJSFSMOFG      Awendo
# 5539    12935         21B          Mpesa      2MLD47XLVU      Awendo
# 5528    12924         16B          Mpesa      6KYCTDYHDJ      Awendo
#
#      travel_to car_type  max_capacity  tickets_booked           date_time  \
# 502    Nairobi      Bus            49               2 2017-05-12 07:08:00
# 5530   Nairobi      Bus            49              20 2018-01-04 07:08:00
# 5533   Nairobi      Bus            49               2 2018-01-04 07:12:00
# 5539   Nairobi      Bus            49               9 2018-01-04 07:13:00
# 5528   Nairobi      Bus            49              15 2018-01-04 08:00:00
#
#       ...  delay_btw_initial_to_next_and_previous_bus  \
# ...

# %%
# Dropping Constant features or not required ones
new_df = new_df.drop(['ride_id','seat_number','payment_receipt','travel_to','payment_method'],axis=1)
new_df.head()
# Out:
#      travel_from car_type  max_capacity  tickets_booked           date_time  \
# 502       Awendo      Bus            49               2 2017-05-12 07:08:00
# 5530      Awendo      Bus            49              20 2018-01-04 07:08:00
# 5533      Awendo      Bus            49               2 2018-01-04 07:12:00
# 5539      Awendo      Bus            49               9 2018-01-04 07:13:00
# 5528      Awendo      Bus            49              15 2018-01-04 08:00:00
#
#       month  year  hour  day_of_year  day_of_month  ...  \
# 502       5  2017     7          132            12  ...
# 5530      1  2018     7            4             4  ...
# 5533      1  2018     7            4             4  ...
# 5539      1  2018     7            4             4  ...
# 5528      1  2018     8            4             4  ...
#
#       delay_btw_initial_to_next_and_previous_bus  delay_btw_1bus_and_next_bus  \
# 502                                  5688.066667                 -5688.000000
# ...

# %%
# Checking for missing values
new_df.isna().sum()
# Out:
# travel_from                                   0
# car_type                                      0
# max_capacity                                  0
# tickets_booked                                0
# date_time                                     0
# month                                         0
# year                                          0
# hour                                          0
# day_of_year                                   0
# day_of_month                                  0
# day_of_week                                   0
# quarter_of_year                               0
# weekend_travels                               0
# travelling_period                             0
# hourly_travellers                             0
# daily_travellers                              0
# delay_btw_initial_to_next_and_previous_bus    0
# delay_btw_1bus_and_next_bus                   0
# delay_btw_1bus_and_previous_bus               0
# delay_btw_2bus_and_next_bus                   0
# ...

# %%
# Checking for Outliers
new_df.describe()
# Out:
#        max_capacity  tickets_booked        month         year         hour  \
# count   6246.000000     6246.000000  6246.000000  6246.000000  6246.000000
# mean      30.383285        8.267531     5.762248  2017.738072     7.949568
# std       18.997654        8.633893     4.076686     0.439719     2.948208
# min       11.000000        1.000000     1.000000  2017.000000     5.000000
# 25%       11.000000        2.000000     2.000000  2017.000000     7.000000
# 50%       49.000000        7.000000     4.000000  2018.000000     7.000000
# 75%       49.000000       11.000000    10.000000  2018.000000     8.000000
# max       49.000000       50.000000    12.000000  2018.000000    23.000000
#
#        day_of_year  day_of_month  day_of_week  quarter_of_year  \
# count  6246.000000   6246.000000  6246.000000      6246.000000
# mean    158.058277     13.830772     2.914025         2.233109
# std     122.237428      9.302135     1.958040         1.265708
# ...

# %%
#checking for multicolinearity
correlation = new_df.corr()
sns.heatmap(abs(correlation),annot=True,cmap='coolwarm')
# Out:
# <ipython-input-55-b56254d55e9e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = new_df.corr()
# <Axes: >

# %%
#There is very much colinearity between 'day_of_year', 'month' and 'year'
#dropping column 'day_of_year'
new_df.drop(['day_of_year'],inplace=True,axis=1)

# %%
correlation = new_df.corr()
sns.heatmap(abs(correlation),annot=True,cmap='coolwarm')
# Out:
# <ipython-input-57-6252d556a2ae>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = new_df.corr()
# <Axes: >

# %%
#data encoding
from sklearn import preprocessing #Import LabelEncoder
cat_features = ['travel_from','travelling_period']
new_df = pd.get_dummies(new_df, columns=cat_features)
label_enc = {'Bus':1, 'shuttle':0}
new_df.car_type.replace(label_enc, inplace= True)
label_enc2 = {'49':1, '11':0}
new_df.max_capacity.replace(label_enc2,inplace=True)

# %%
new_df.head()
# Out:
#       car_type  max_capacity  tickets_booked           date_time  month  year  \
# 502          1            49               2 2017-05-12 07:08:00      5  2017
# 5530         1            49              20 2018-01-04 07:08:00      1  2018
# 5533         1            49               2 2018-01-04 07:12:00      1  2018
# 5539         1            49               9 2018-01-04 07:13:00      1  2018
# 5528         1            49              15 2018-01-04 08:00:00      1  2018
#
#       hour  day_of_month  day_of_week  quarter_of_year  ...  \
# 502      7            12            4                2  ...
# 5530     7             4            3                1  ...
# 5533     7             4            3                1  ...
# 5539     7             4            3                1  ...
# 5528     8             4            3                1  ...
#
#       travel_from_Migori  travel_from_Ndhiwa  travel_from_Nyachenge  \
# ...

# %% [markdown]
# # Model Implementation

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
#independent and dependent feature
X= new_df.drop(['tickets_booked','date_time'],axis=1).copy()    #independent features
y= new_df.tickets_booked.copy()                                 #dependent features

# %%
#train test split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30, random_state=12)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (4372, 39)
# (1874, 39)

# %% [markdown]
# ### Linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
reg.score(X_train, y_train)
# Out:
# 0.41119828893639254

# %%
y_pred = reg.predict(X_test)
y_pred
# Out:
# array([ 4.40608254, 10.40223822,  6.71733433, ...,  7.54405546,
#        -0.83559231,  6.29676333])

# %%
y_pred_train = reg.predict(X_train)
y_pred_train
# Out:
# array([10.69921887,  4.14618194,  6.88752241, ...,  0.88946777,
#         6.28031798,  4.7122702 ])

# %%
#checking evaluation metrics
MSE  = mean_squared_error(y_test, y_pred)
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# MSE : 47.82053329486215
# RMSE : 6.915239207349385

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print("R2 :" ,r2)
# Out:
# R2 : 0.38469597848977555

# %% [markdown]
# ### lasso regression

# %%
from sklearn.linear_model import Lasso

# %%
#tried with different alpha values  (0.2,0.02.0.1,0.01,0.5,0.125), but 0.01 got better than rest
l1 = Lasso(alpha=0.01,max_iter=1000)

# %%
l1.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.572e+02, tolerance: 3.197e+01
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.01)

# %%
y_pred_lasso = l1.predict(X_test)

# %%
l1.score(X_test,y_test)
# Out:
# 0.3827353508405148

# %%
MSE  = mean_squared_error(y_test, y_pred_lasso)
print("MSE :" , MSE)

RMSE = np.sqrt(MSE)
print("RMSE :" ,RMSE)
# Out:
# MSE : 47.97291042308273
# RMSE : 6.926247932544917

# %%
r2 = r2_score(y_test, y_pred_lasso)
print("R2 :" ,r2)
# Out:
# R2 : 0.3827353508405148

# %% [markdown]
# ### Ridge regression

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
l2= Ridge()
parameter ={ "alpha":[0.2]}

# %%
#hyperparameter tuning
ridge_regressor = GridSearchCV(l2,parameter, scoring='neg_mean_squared_error', cv=5)
ridge_regressor.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(), param_grid={'alpha': [0.2]},
#              scoring='neg_mean_squared_error')

# %%
#model predictions
reg_pred = ridge_regressor.predict(X_test)

# %%
ridge_regressor.score(X_test,y_test)
# Out:
# -47.81399792134218

# %%
r2 = r2_score(y_test, reg_pred)
print("R2 :" ,r2)
# Out:
# R2 : 0.38478006876087556

# %% [markdown]
# ### Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error

# %%
rf_reg = RandomForestRegressor(criterion = 'squared_error',max_leaf_nodes = 9, random_state = 12)
rf_reg.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_leaf_nodes=9, random_state=12)

# %%
#predicting the train values
rf_reg_pred_train = rf_reg.predict(X_train)

# %%
#predicting the test values
rf_reg_pred_test = rf_reg.predict(X_test)

# %%
print('Regressor train score :', rf_reg.score(X_train,y_train) )
print('Regressor test score :', rf_reg.score(X_test,y_test) )
# Out:
# Regressor train score : 0.538961131323595
# Regressor test score : 0.4973436684157385

# %%
# eval matrics
MSE = mean_squared_error(y_train, rf_reg_pred_train)
print('mse:',MSE)

RMSE = np.sqrt(MSE)
print('rmse',RMSE)

MAE = mean_absolute_error(y_train, rf_reg_pred_train)
print('MAE:',MAE)

MAPE = mean_absolute_percentage_error(y_train,rf_reg_pred_train)
print('MAPE:',MAPE)

r2 = r2_score(y_train,rf_reg_pred_train)
print('R2:',r2)
print('adjusted R2:',1-(1-r2_score(y_train, rf_reg_pred_train))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# mse: 33.71066814640777
# rmse 5.806088885506988
# MAE: 3.979710366863598
# MAPE: 1.3427768409461418
# R2: 0.538961131323595
# adjusted R2: 0.5291571422950346

# %%
# eval matrics
MSE = mean_squared_error(y_test, rf_reg_pred_test)
print('mse:',MSE)

RMSE = np.sqrt(MSE)
print('rmse',RMSE)

MAE = mean_absolute_error(y_test, rf_reg_pred_test)
print('MAE:',MAE)

MAPE = mean_absolute_percentage_error(y_test,rf_reg_pred_test)
print('MAPE:',MAPE)

r2 = r2_score(y_test,rf_reg_pred_test)
print('R2:',r2)
print('adjusted R2:',1-(1-r2_score(y_test, rf_reg_pred_test))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# mse: 39.06571873429406
# rmse 6.250257493439295
# MAE: 4.246083395178705
# MAPE: 1.4218022669944375
# R2: 0.4973436684157385
# adjusted R2: 0.4866546842653644

# %% [markdown]
# ### GridSearch CV on Random Forest

# %%
from sklearn.model_selection import GridSearchCV
from pprint import pprint

# %%
rfrg = RandomForestRegressor()

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 400, stop = 1000, num = 4)]

# no. of features to take at each split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(40, 100, num = 4)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [5, 10, 12]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the parameters grid
grid_params_dict = grid_params_dict = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
pprint(grid_params_dict)
# Out:
# {'bootstrap': [True, False],
#  'max_depth': [40, 60, 80, 100, None],
#  'max_features': ['auto', 'sqrt'],
#  'min_samples_leaf': [1, 2, 4],
#  'min_samples_split': [5, 10, 12],
#  'n_estimators': [400, 600, 800, 1000]}

# %%
rf_gridcv = GridSearchCV(estimator=rfrg,param_grid = grid_params_dict, cv=3, verbose =2, n_jobs= -1)
rf_gridcv.fit(X,y)
# Out:
# Fitting 3 folds for each of 720 candidates, totalling 2160 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [40, 60, 80, 100, None],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [5, 10, 12],
#                          'n_estimators': [400, 600, 800, 1000]},
#              verbose=2)

# %%
# Viewing the best parameters of the optimal model
rf_gridcv.best_params_

# %%
rf_gridcv.best_estimator_
# Out:
# RandomForestRegressor(max_depth=60, max_features='sqrt', min_samples_leaf=4,
#                       min_samples_split=5, n_estimators=600)

# %%
# Predicting the values of training data using the calculated optimal model
rf_grid_optimal_model =rf_gridcv.best_estimator_
y_train_pred_gridCV = rf_grid_optimal_model.predict(X_train)

# %%
#for train data
MSE = mean_squared_error(y_train, y_train_pred_gridCV)
print('mse:',MSE)

RMSE = np.sqrt(MSE)
print('rmse',RMSE)

MAE = mean_absolute_error(y_train, y_train_pred_gridCV)
print('MAE:',MAE)

MAPE = mean_absolute_percentage_error(y_train,y_train_pred_gridCV)
print('MAPE:',MAPE)

r2 = r2_score(y_train,y_train_pred_gridCV)
print('R2:',r2)
print('adjusted R2:',1-(1-r2_score(y_train, y_train_pred_gridCV))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# mse: 15.929128219264571
# rmse 3.991131195446295
# MAE: 2.5243822485571403
# MAPE: 0.7519403517263322
# R2: 0.7821476803332446
# adjusted R2: 0.7775150519433844

# %%
# Predicting the target values of test data using calculated best model
y_test_pred_gridCV = rf_grid_optimal_model.predict(X_test)

# %%
#for test data
MSE = mean_squared_error(y_test, y_test_pred_gridCV)
print('mse:',MSE)

RMSE = np.sqrt(MSE)
print('rmse',RMSE)

MAE = mean_absolute_error(y_test, y_test_pred_gridCV)
print('MAE:',MAE)

MAPE = mean_absolute_percentage_error(y_test,y_test_pred_gridCV)
print('MAPE:',MAPE)

r2 = r2_score(y_test,y_test_pred_gridCV)
print('R2:',r2)
print('adjusted R2:',1-(1-r2_score(y_test, y_test_pred_gridCV))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# mse: 17.443427241129122
# rmse 4.176532921111615
# MAE: 2.6662251282867064
# MAPE: 0.8165340591319671
# R2: 0.775556435888997
# adjusted R2: 0.7707836447219691

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb

# %%
X= new_df.drop(['tickets_booked','date_time'],axis=1).copy()
y= new_df.tickets_booked.copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30, random_state=12)

# %%
#training basic model
xgb_reg = xgb.XGBRegressor(objective='reg:squarederror')
xgb_reg.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
xgb_reg_train_pred = xgb_reg.predict(X_train)

# %%
xgb_reg_test_pred = xgb_reg.predict(X_test)

# %%
print('Regressor train score :', xgb_reg.score(X_train,y_train) )
print('Regressor test score :', xgb_reg.score(X_test,y_test) )
# Out:
# Regressor train score : 0.9577599144277424
# Regressor test score : 0.6035761197334144

# %%
MSE = mean_squared_error(y_train, xgb_reg_train_pred)
print('mse:',MSE)

RMSE = np.sqrt(MSE)
print('rmse:',RMSE)

MAE = mean_absolute_error(y_train, xgb_reg_train_pred)
print('MAE:',MAE)

MAPE = mean_absolute_percentage_error(y_train,xgb_reg_train_pred)
print('MAPE:',MAPE)

r2 = r2_score(y_train,xgb_reg_train_pred)
print('R2:',r2)
print('adjusted R2:',1-(1-r2_score(y_train, xgb_reg_train_pred))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# mse: 3.088549803382584
# rmse: 1.7574270406997226
# MAE: 1.2528475954993827
# MAPE: 0.3668794244211002
# R2: 0.9577599144277424
# adjusted R2: 0.9568616792383651

# %%
MSE = mean_squared_error(y_test, xgb_reg_test_pred)
print('mse:',MSE)

RMSE = np.sqrt(MSE)
print('rmse',RMSE)

MAE = mean_absolute_error(y_test, xgb_reg_test_pred)
print('MAE:',MAE)

MAPE = mean_absolute_percentage_error(y_test,xgb_reg_test_pred)
print('MAPE:',MAPE)

r2 = r2_score(y_test,xgb_reg_test_pred)
print('R2:',r2)
print('adjusted R2:',1-(1-r2_score(y_test, xgb_reg_test_pred))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# mse: 30.809487184298685
# rmse 5.550629440369685
# MAE: 3.5162316834297638
# MAPE: 1.0786825178244752
# R2: 0.6035761197334144
# adjusted R2: 0.5951461680810716

# %% [markdown]
# ### GridSearch CV on XGBoost

# %%
xgboost_reg = xgb.XGBRegressor()

# %%
# Fraction of columns to be randomly samples for each tree
colsample_bytree= [0.1, 0.3, 0.5, 0.7, 0.9]
eta = [0.0001, 0.0004, 0.001, 0.004]

# Magnitude of this change in the estimates
learning_rate=  [0.01, 0.05, 0.1]

# Maximum number of levels in tree
max_depth= [6, 8, 10, 12]
min_child_weight= [7, 8, 10, 12]

# Number of trees in random forest
n_estimators= [70, 100, 120]

#Fraction of observations to be selected for each tree
subsample= [0.5, 0.7, 0.9, 1]

# Create the random grid
xgb_grid_params_dict = {'colsample_bytree': colsample_bytree,
         'eta': eta,
         'learning_rate': learning_rate,
         'max_depth': max_depth,
         'min_child_weight': min_child_weight,
         'n_estimators': n_estimators,
         'subsample': subsample}
pprint(xgb_grid_params_dict)
# Out:
# {'colsample_bytree': [0.1, 0.3, 0.5, 0.7, 0.9],
#  'eta': [0.0001, 0.0004, 0.001, 0.004],
#  'learning_rate': [0.01, 0.05, 0.1],
#  'max_depth': [6, 8, 10, 12],
#  'min_child_weight': [7, 8, 10, 12],
#  'n_estimators': [70, 100, 120],
#  'subsample': [0.5, 0.7, 0.9, 1]}

# %%
xgboost_reg =  xgb.XGBRegressor(objective='reg:squarederror',random_state=12)
xgboost_reg_grid = GridSearchCV(estimator=xgboost_reg, param_grid= xgb_grid_params_dict, cv= 3, verbose = 2, n_jobs = -1)
xgboost_reg_grid.fit(X,y)
# Out:
# Fitting 3 folds for each of 11520 candidates, totalling 34560 fits
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
# ...

# %%
xgboost_reg_grid.best_estimator_
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.5, early_stopping_rounds=None,
#              enable_categorical=False, eta=0.0001, eval_metric=None,
#              feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#              max_leaves=None, min_child_weight=8, missing=nan,
#              monotone_constraints=None, n_estimators=70, n_jobs=None,
#              num_parallel_tree=None, predictor=None, ...)

# %%
#for optimal model
optimal_xgboost = xgboost_reg_grid.best_estimator_
xgb_cv_train_pred = optimal_xgboost.predict(X_train)
xgb_cv_test_pred =  optimal_xgboost.predict(X_test)

# %%
MSE = mean_squared_error(y_train, xgb_cv_train_pred)
print('mse:',MSE)

RMSE = np.sqrt(MSE)
print('rmse:',RMSE)

MAE = mean_absolute_error(y_train, xgb_cv_train_pred)
print('MAE:',MAE)

MAPE = mean_absolute_percentage_error(y_train,xgb_cv_train_pred)
print('MAPE:',MAPE)

r2 = r2_score(y_train,xgb_cv_train_pred)
print('R2:',r2)
print('adjusted R2:',1-(1-r2_score(y_train, xgb_cv_train_pred))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# mse: 11.63569896744318
# rmse: 3.4111140361241485
# MAE: 2.2695434383633875
# MAPE: 0.6655272704068756
# R2: 0.8408661179626942
# adjusted R2: 0.8374821368288583

# %%
MSE = mean_squared_error(y_test, xgb_cv_test_pred)
print('mse:',MSE)

RMSE = np.sqrt(MSE)
print('rmse',RMSE)

MAE = mean_absolute_error(y_test, xgb_cv_test_pred)
print('MAE:',MAE)

MAPE = mean_absolute_percentage_error(y_test,xgb_cv_test_pred)
print('MAPE:',MAPE)

r2 = r2_score(y_test,xgb_cv_test_pred)
print('R2:',r2)
print('adjusted R2:',1-(1-r2_score(y_test, xgb_cv_test_pred))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)))
# Out:
# mse: 12.365898172579612
# rmse 3.51651790448728
# MAE: 2.334304209532198
# MAPE: 0.7010145491336218
# R2: 0.840888707194914
# adjusted R2: 0.8375052064209783

# %% [markdown]
# ### Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# I implemented 5 models with evaluation matrics and in that I have preferred r2 and adjusted r2 score.
# Out of all, hyperparameters tuned XGBoost Regressor algorithm gives the best results with an accuracy of around 84%.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Conclusion of EDA:
#
#
#
# 1.  Mpesa is most used payment method
# 2.  Kisii is most 'travelled from' place
# 3.  In Kisii and Kijauri shuttle are used more than buses Where as in rest of the origin place buses are dominating the market.
# 4. There is not ride between 11:30am to 5:30Pm from any origin. And everyday at 7am most tickets are sold compared to any other hour of day.
# 5. Most of the tickets were sold between November and May.
#
# Conclusion of Model implementation:
#
# I tried 5 models:
#
# 1. Linear Regression
#
# 2. Ridge Regression
#
# 3. Lasso Regression & tuned hyperparameter with GridSearch CV
#
# 4. Random Forest Regression & tuned hyperparameter with GridSearch CV
#
# 5.  XGBoost Regression & tuned hyperparameter with GridSearch CV
#
#
#
# And out of all hyperparameters tuned XGBoost Regressor algorithm gives the best results with an accuracy of around 84%.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
